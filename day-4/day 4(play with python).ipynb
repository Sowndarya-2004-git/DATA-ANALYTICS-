# %% [markdown]
# To print First 5 rows

# %%
import pandas as pd
import numpy as np
file_name="career_change_prediction_dataset.csv"
df=pd.read_csv(file_name)
df.head(6) #first 6 rows
# Out:
#   Field of Study Current Occupation  Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst   48    Male                    7
# 1      Education          Economist   44    Male                   26
# 2      Education          Biologist   21  Female                   27
# 3      Education   Business Analyst   33    Male                   14
# 4           Arts             Doctor   28  Female                    0
# 5       Medicine             Lawyer   56    Male                   39
#
#   Education Level Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0     High School                 High                 7                 10
# 1        Master's                  Low                10                  3
# 2        Master's                  Low                 8                  3
# 3             PhD               Medium                 7                  9
# 4             PhD                  Low                 3                  1
# ...

# %% [markdown]
# To print Last 5 rows

# %%
df.tail(10)  # Display last 10 rows
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 38434                 Biology   Software Developer   37  Female
# 38435                Business            Biologist   25    Male
# 38436  Mechanical Engineering            Economist   30    Male
# 38437                 Biology            Biologist   44  Female
# 38438                 Biology     Business Analyst   55    Male
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 38434                   24      Bachelor's                 High
# 38435                   25     High School               Medium
# 38436                    6      Bachelor's                 High
# ...

# %% [markdown]
# To print Random sample of 5 rows

# %%
df.sample(5)  # Random sample of 5 rows
# Out:
#          Field of Study  Current Occupation  Age  Gender  Years of Experience  \
# 21211  Computer Science        Psychologist   21  Female                    6
# 14786          Business             Teacher   22  Female                    9
# 18735         Education              Doctor   45  Female                   33
# 26691          Medicine           Economist   49  Female                   23
# 577             Biology  Software Developer   59    Male                   26
#
#       Education Level Industry Growth Rate  Job Satisfaction  \
# 21211     High School                 High                 4
# 14786     High School               Medium                 8
# 18735        Master's               Medium                10
# 26691             PhD                  Low                 9
# 577          Master's               Medium                 1
#
#        Work-Life Balance  Job Opportunities  ...  Skills Gap  \
# 21211                  9                 24  ...           4
# ...

# %% [markdown]
# To print Dataset structure

# %%
df.info()  # Dataset structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38444 entries, 0 to 38443
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Field of Study               38444 non-null  object
#  1   Current Occupation           38444 non-null  object
#  2   Age                          38444 non-null  int64
#  3   Gender                       38444 non-null  object
#  4   Years of Experience          38444 non-null  int64
#  5   Education Level              38444 non-null  object
#  6   Industry Growth Rate         38444 non-null  object
#  7   Job Satisfaction             38444 non-null  int64
#  8   Work-Life Balance            38444 non-null  int64
#  9   Job Opportunities            38444 non-null  int64
#  10  Salary                       38444 non-null  int64
#  11  Job Security                 38444 non-null  int64
#  12  Career Change Interest       38444 non-null  int64
# ...

# %% [markdown]
# Summary statistics

# %%
df.describe()  # Summary statistics
# Out:
#                 Age  Years of Experience  Job Satisfaction  Work-Life Balance  \
# count  38444.000000         38444.000000      38444.000000       38444.000000
# mean      39.540422            19.548200          5.489673           5.517012
# std       11.574509            11.552474          2.870407           2.879007
# min       20.000000             0.000000          1.000000           1.000000
# 25%       30.000000            10.000000          3.000000           3.000000
# 50%       40.000000            20.000000          6.000000           6.000000
# 75%       50.000000            30.000000          8.000000           8.000000
# max       59.000000            39.000000         10.000000          10.000000
#
#        Job Opportunities         Salary  Job Security  Career Change Interest  \
# count       38444.000000   38444.000000  38444.000000            38444.000000
# mean           50.308267  114975.623999      5.481896                0.199901
# ...

# %% [markdown]
# Dimensions of dataset

# %%
df.shape  # Dimensions of dataset
# Out:
# (38444, 23)

# %% [markdown]
# Total number of elements

# %%
df.size  # Total number of elements
# Out:
# 884212

# %% [markdown]
# Column names

# %%
df.columns  # Column names
# Out:
# Index(['Field of Study', 'Current Occupation', 'Age', 'Gender',
#        'Years of Experience', 'Education Level', 'Industry Growth Rate',
#        'Job Satisfaction', 'Work-Life Balance', 'Job Opportunities', 'Salary',
#        'Job Security', 'Career Change Interest', 'Skills Gap',
#        'Family Influence', 'Mentorship Available', 'Certifications',
#        'Freelancing Experience', 'Geographic Mobility',
#        'Professional Networks', 'Career Change Events', 'Technology Adoption',
#        'Likely to Change Occupation'],
#       dtype='object')

# %% [markdown]
# #Index range

# %%
df.index  # Index range
# Out:
# RangeIndex(start=0, stop=38444, step=1)

# %% [markdown]
# # Memory usage of each column

# %%
df.memory_usage()  # Memory usage of each column
# Out:
# Index                             128
# Field of Study                 307552
# Current Occupation             307552
# Age                            307552
# Gender                         307552
# Years of Experience            307552
# Education Level                307552
# Industry Growth Rate           307552
# Job Satisfaction               307552
# Work-Life Balance              307552
# Job Opportunities              307552
# Salary                         307552
# Job Security                   307552
# Career Change Interest         307552
# Skills Gap                     307552
# Family Influence               307552
# Mentorship Available           307552
# Certifications                 307552
# Freelancing Experience         307552
# Geographic Mobility            307552
# Professional Networks          307552
# Career Change Events           307552
# Technology Adoption            307552
# Likely to Change Occupation    307552
# dtype: int64

# %% [markdown]
# # Count of unique values in each column

# %%
df.nunique()  # Count of unique values in each column
# Out:
# Field of Study                    10
# Current Occupation                10
# Age                               40
# Gender                             2
# Years of Experience               40
# Education Level                    4
# Industry Growth Rate               3
# Job Satisfaction                  10
# Work-Life Balance                 10
# Job Opportunities                100
# Salary                         34551
# Job Security                      10
# Career Change Interest             2
# Skills Gap                        10
# Family Influence                   3
# Mentorship Available               2
# Certifications                     2
# Freelancing Experience             2
# Geographic Mobility                2
# Professional Networks             10
# Career Change Events               3
# Technology Adoption               10
# Likely to Change Occupation        2
# dtype: int64

# %% [markdown]
# # Data types of each column

# %%
df.dtypes  # Data types of each column
# Out:
# Field of Study                 object
# Current Occupation             object
# Age                             int64
# Gender                         object
# Years of Experience             int64
# Education Level                object
# Industry Growth Rate           object
# Job Satisfaction                int64
# Work-Life Balance               int64
# Job Opportunities               int64
# Salary                          int64
# Job Security                    int64
# Career Change Interest          int64
# Skills Gap                      int64
# Family Influence               object
# Mentorship Available            int64
# Certifications                  int64
# Freelancing Experience          int64
# Geographic Mobility             int64
# Professional Networks           int64
# Career Change Events            int64
# Technology Adoption             int64
# Likely to Change Occupation     int64
# dtype: object

# %% [markdown]
# # Count missing values per column

# %%
df.isnull().sum()  # Count missing values per column
# Out:
# Field of Study                    0
# Current Occupation                0
# Age                               0
# Gender                            0
# Years of Experience               0
# Education Level                   0
# Industry Growth Rate              0
# Job Satisfaction                  0
# Work-Life Balance                 0
# Job Opportunities                 0
# Salary                            0
# Job Security                      0
# Career Change Interest            0
# Skills Gap                        0
# Family Influence               9632
# Mentorship Available              0
# Certifications                    0
# Freelancing Experience            0
# Geographic Mobility               0
# Professional Networks             0
# Career Change Events              0
# Technology Adoption               0
# Likely to Change Occupation       0
# dtype: int64

# %% [markdown]
#  # Count non-missing values per column

# %%
df.notnull().sum()  # Count non-missing values per column
# Out:
# Field of Study                 38444
# Current Occupation             38444
# Age                            38444
# Gender                         38444
# Years of Experience            38444
# Education Level                38444
# Industry Growth Rate           38444
# Job Satisfaction               38444
# Work-Life Balance              38444
# Job Opportunities              38444
# Salary                         38444
# Job Security                   38444
# Career Change Interest         38444
# Skills Gap                     38444
# Family Influence               28812
# Mentorship Available           38444
# Certifications                 38444
# Freelancing Experience         38444
# Geographic Mobility            38444
# Professional Networks          38444
# Career Change Events           38444
# Technology Adoption            38444
# Likely to Change Occupation    38444
# dtype: int64

# %% [markdown]
# # Count duplicated rows

# %%
df.duplicated().sum()  # Count duplicated rows
# Out:
# 0

# %% [markdown]
#  # Drop duplicate rows

# %%
df.drop_duplicates()  # Drop duplicate rows
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48    Male
# 1                   Education            Economist   44    Male
# 2                   Education            Biologist   21  Female
# 3                   Education     Business Analyst   33    Male
# 4                        Arts               Doctor   28  Female
# ...                       ...                  ...  ...     ...
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %% [markdown]
#  # Reset index

# %%
df.reset_index(drop=True)  # Reset index
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48    Male
# 1                   Education            Economist   44    Male
# 2                   Education            Biologist   21  Female
# 3                   Education     Business Analyst   33    Male
# 4                        Arts               Doctor   28  Female
# ...                       ...                  ...  ...     ...
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %% [markdown]
#  # Rename a column

# %%
df.rename(columns={'old_col': 'new_col'}, inplace=True)  # Rename a column

# %% [markdown]
#   # Sort by 'Age'

# %%
df.sort_values('Age', ascending=True)  # Sort by 'Age'
# Out:
#       Field of Study  Current Occupation  Age  Gender  Years of Experience  \
# 5495         Biology           Biologist   20    Male                   17
# 35069      Economics              Lawyer   20  Female                   24
# 35070       Medicine              Lawyer   20  Female                    4
# 3911         Biology              Doctor   20  Female                   16
# 23819       Business  Software Developer   20    Male                   26
# ...              ...                 ...  ...     ...                  ...
# 36771        Biology             Teacher   59    Male                    3
# 18612       Medicine             Teacher   59    Male                    5
# 11155      Economics           Economist   59  Female                   33
# 18571            Law              Artist   59    Male                   18
# 15652       Business              Artist   59    Male                   29
#
#       Education Level Industry Growth Rate  Job Satisfaction  \
# ...

# %% [markdown]
#  # Top 10 rows with largest 'Salary'

# %%
df.nlargest(10, 'Salary')  # Top 10 rows with largest 'Salary'
# Out:
#          Field of Study  Current Occupation  Age  Gender  Years of Experience  \
# 24970  Computer Science  Software Developer   31    Male                    5
# 19200  Computer Science    Business Analyst   43    Male                   15
# 19383               Law        Psychologist   30    Male                   37
# 35158         Education           Biologist   58    Male                   29
# 15413           Biology        Psychologist   21  Female                    4
# 30044               Law              Artist   23  Female                   17
# 4287           Business             Teacher   52  Female                   33
# 15895         Economics           Biologist   53  Female                   15
# 4904               Arts              Artist   48    Male                   22
# 36221  Computer Science  Software Developer   24  Female                    5
#
#       Education Level Industry Growth Rate  Job Satisfaction  \
# ...

# %% [markdown]
#  # Top 10 rows with smallest 'Salary'

# %%
df.nsmallest(10, 'Salary')  # Top 10 rows with smallest 'Salary'
# Out:
#                Field of Study Current Occupation  Age  Gender  \
# 6918                  Biology   Business Analyst   35    Male
# 13183                    Arts       Psychologist   32  Female
# 25837                Business   Business Analyst   39  Female
# 9238         Computer Science             Doctor   24    Male
# 1066   Mechanical Engineering   Business Analyst   39    Male
# 13870                Medicine             Lawyer   45    Male
# 9274                 Medicine            Teacher   38  Female
# 34742                Medicine          Economist   22  Female
# 34796                    Arts            Teacher   40  Female
# 13809               Education             Doctor   51  Female
#
#        Years of Experience Education Level Industry Growth Rate  \
# 6918                    37             PhD               Medium
# 13183                   29             PhD                  Low
# 25837                   22        Master's                 High
# ...

# %% [markdown]
# # Correlation matrix

# %%
df.select_dtypes(include=['number']).corr() # Correlation matrix
# Out:
#                                   Age  Years of Experience  Job Satisfaction  \
# Age                          1.000000             0.003682          0.001191
# Years of Experience          0.003682             1.000000         -0.005106
# Job Satisfaction             0.001191            -0.005106          1.000000
# Work-Life Balance            0.004900            -0.003602         -0.006912
# Job Opportunities            0.002576             0.003335         -0.002664
# Salary                       0.003683             0.000032         -0.004733
# Job Security                 0.005077             0.005392          0.003433
# Career Change Interest      -0.001451             0.001245          0.002444
# Skills Gap                  -0.002010            -0.002583         -0.004738
# Mentorship Available        -0.008865             0.000569         -0.001393
# Certifications               0.001223             0.001765          0.000130
# ...

# %% [markdown]
# # Covariance matrix

# %%
df.select_dtypes(include=['number']).cov() # Covariance matrix
# Out:
#                                      Age  Years of Experience  \
# Age                           133.969258             0.492329
# Years of Experience             0.492329           133.459659
# Job Satisfaction                0.039579            -0.169312
# Work-Life Balance               0.163269            -0.119788
# Job Opportunities               0.860949             1.112616
# Salary                       2087.058835            18.238099
# Job Security                    0.168695             0.178811
# Career Change Interest         -0.006715             0.005751
# Skills Gap                     -0.066782            -0.085628
# Mentorship Available           -0.047021             0.003010
# Certifications                  0.006476             0.009330
# Freelancing Experience          0.019149             0.038798
# Geographic Mobility             0.028240            -0.004611
# Professional Networks           0.049166            -0.263185
# ...

# %% [markdown]
#  # Kurtosis of each column

# %%
df.select_dtypes(include=['number']).kurtosis()  # Kurtosis of each column
# Out:
# Age                           -1.207236
# Years of Experience           -1.201641
# Job Satisfaction              -1.219557
# Work-Life Balance             -1.227408
# Job Opportunities             -1.206335
# Salary                        -1.193032
# Job Security                  -1.221891
# Career Change Interest         0.252507
# Skills Gap                    -1.217725
# Mentorship Available          -1.237581
# Certifications                -1.225470
# Freelancing Experience         1.878002
# Geographic Mobility           -1.273532
# Professional Networks         -1.220119
# Career Change Events          -1.497978
# Technology Adoption           -1.212618
# Likely to Change Occupation   -1.904075
# dtype: float64

# %% [markdown]
#  # Skewness of each column

# %%
df.select_dtypes(include=['number']).skew()  # Skewness of each column
# Out:
# Age                           -0.005949
# Years of Experience           -0.008195
# Job Satisfaction              -0.000294
# Work-Life Balance             -0.002051
# Job Opportunities              0.008359
# Salary                         0.006568
# Job Security                   0.006157
# Career Change Interest         1.500831
# Skills Gap                    -0.013343
# Mentorship Available           0.873203
# Certifications                 0.880110
# Freelancing Experience         1.969239
# Geographic Mobility            0.852370
# Professional Networks         -0.008737
# Career Change Events          -0.006065
# Technology Adoption            0.007797
# Likely to Change Occupation   -0.309877
# dtype: float64

# %% [markdown]
# # Drop rows with missing values

# %%
df.select_dtypes(include=['number']).dropna()  # Drop rows with missing values
# Out:
#        Age  Years of Experience  Job Satisfaction  Work-Life Balance  \
# 0       48                    7                 7                 10
# 1       44                   26                10                  3
# 2       21                   27                 8                  3
# 3       33                   14                 7                  9
# 4       28                    0                 3                  1
# ...    ...                  ...               ...                ...
# 38439   24                   34                 8                  1
# 38440   21                   24                 2                  7
# 38441   35                   21                 4                 10
# 38442   35                   11                 9                  4
# 38443   37                   23                 6                  2
#
#        Job Opportunities  Salary  Job Security  Career Change Interest  \
# ...

# %% [markdown]
#   # Fill missing values with 0

# %%
df.fillna(0, inplace=True)  # Fill missing values with 0

# %% [markdown]
#  # Count rows with specific values

# %%
df.isin(['value1', 'value2']).sum()  # Count rows with specific values
# Out:
# Field of Study                 0
# Current Occupation             0
# Age                            0
# Gender                         0
# Years of Experience            0
# Education Level                0
# Industry Growth Rate           0
# Job Satisfaction               0
# Work-Life Balance              0
# Job Opportunities              0
# Salary                         0
# Job Security                   0
# Career Change Interest         0
# Skills Gap                     0
# Family Influence               0
# Mentorship Available           0
# Certifications                 0
# Freelancing Experience         0
# Geographic Mobility            0
# Professional Networks          0
# Career Change Events           0
# Technology Adoption            0
# Likely to Change Occupation    0
# dtype: int64

# %% [markdown]
#  # Query rows with conditions

# %%
df.query("Age > 30 and Salary < 50000")  # Query rows with conditions
# Out:
#          Field of Study   Current Occupation  Age  Gender  \
# 20              Biology     Business Analyst   35  Female
# 26             Business            Economist   50    Male
# 32           Psychology  Mechanical Engineer   31    Male
# 54            Education            Economist   43    Male
# 62            Education  Mechanical Engineer   49    Male
# ...                 ...                  ...  ...     ...
# 38382  Computer Science               Doctor   38  Female
# 38386               Law     Business Analyst   58  Female
# 38403         Economics  Mechanical Engineer   53    Male
# 38416        Psychology               Artist   38  Female
# 38417           Biology               Artist   48  Female
#
#        Years of Experience Education Level Industry Growth Rate  \
# 20                      15        Master's               Medium
# 26                      38        Master's               Medium
# 32                       4      Bachelor's               Medium
# ...

# %% [markdown]
#  # Mean of salary column

# %%
df['Salary'].mean()  # Mean of salary column
# Out:
# 114975.62399854333

# %% [markdown]
#   # Median of age column

# %%
df['Age'].median()  # Median of age column
# Out:
# 40.0

# %% [markdown]
#  # Standard deviation of age column

# %%
df['Age'].std()  # Standard deviation of age column
# Out:
# 11.574508972495199

# %% [markdown]
# # Maximum salary

# %%
df['Salary'].max()  # Maximum salary
# Out:
# 199996

# %% [markdown]
#  # Minimum salary

# %%
df['Salary'].min()  # Minimum salary
# Out:
# 30005

# %% [markdown]
# # Frequency counts for experience column

# %%
df['Years of Experience'].value_counts()  # Frequency counts for experience column
# Out:
# Years of Experience
# 30    999
# 39    996
# 23    988
# 24    988
# 22    987
# 10    986
# 1     982
# 36    982
# 11    981
# 31    981
# 4     980
# 28    977
# 16    972
# 21    969
# 20    969
# 35    967
# 8     966
# 33    966
# 29    963
# 3     962
# 0     959
# 7     958
# 15    958
# 34    958
# 25    956
# 32    956
# 19    956
# 2     955
# 12    955
# 18    948
# 26    947
# 37    943
# 38    942
# 6     942
# 17    935
# 9     935
# 14    923
# 27    921
# 13    919
# 5     917
# Name: count, dtype: int64

# %% [markdown]
#  # Filter rows where gender is 'Male'

# %%
df[df['Gender'] == 'Male']  # Filter rows where gender is 'Male'
# Out:
#                Field of Study   Current Occupation  Age Gender  \
# 0                    Medicine     Business Analyst   48   Male
# 1                   Education            Economist   44   Male
# 3                   Education     Business Analyst   33   Male
# 5                    Medicine               Lawyer   56   Male
# 11                       Arts               Artist   54   Male
# ...                       ...                  ...  ...    ...
# 38435                Business            Biologist   25   Male
# 38436  Mechanical Engineering            Economist   30   Male
# 38438                 Biology     Business Analyst   55   Male
# 38442                    Arts     Business Analyst   35   Male
# 38443                     Law  Mechanical Engineer   37   Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %% [markdown]
#  # Exclude rows with department 'HR'

# %%
df[~df['Current Occupation'].str.contains('HR')]  # Exclude rows with department 'HR'
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48    Male
# 1                   Education            Economist   44    Male
# 2                   Education            Biologist   21  Female
# 3                   Education     Business Analyst   33    Male
# 4                        Arts               Doctor   28  Female
# ...                       ...                  ...  ...     ...
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %% [markdown]
#  # Create column with name lengths

# %%
df['Name_length'] = df['Current Occupation'].apply(len)  # Create column with name lengths

# %% [markdown]
#  # Log-transform columns

# %%
df[['Salary', 'Years of Experience']].apply(np.log1p)  # Log-transform columns
# Out:
#           Salary  Years of Experience
# 0      12.197370             2.079442
# 1      11.480444             3.295837
# 2      11.096212             3.332205
# 3      11.357347             2.708050
# 4      10.691649             0.000000
# ...          ...                  ...
# 38439  11.676141             3.555348
# 38440  11.794345             3.218876
# 38441  10.920564             3.091042
# 38442  12.052105             2.484907
# 38443  12.154611             3.178054
#
# [38444 rows x 2 columns]

# %% [markdown]
#  # Clip values

# %%
df['Age'] = df['Age'].clip(lower=18, upper=65)  # Clip values

# %% [markdown]
#  # Rank values in columns

# %%
df[['Salary', 'Age']].rank()  # Rank values in columns
# Out:
#         Salary      Age
# 0      38065.0  27340.5
# 1      15065.0  23438.0
# 2       8063.0   1443.0
# 3      12552.5  12910.5
# 4       3081.0   8223.0
# ...        ...      ...
# 38439  19883.0   4372.5
# 38440  23230.0   1443.0
# 38441   5708.5  14821.5
# 38442  32049.0  14821.5
# 38443  36136.0  16780.5
#
# [38444 rows x 2 columns]

# %% [markdown]
#  # Boolean column for high earners

# %%
df['is_high_earner'] = df['Salary'] > 100000  # Boolean column for high earners

# %% [markdown]
#   # Drop column

# %%
df.drop(columns=['Years of Experience'], inplace=True)  # Drop column

# %% [markdown]
#  # Replace categorical values

# %%
df.replace({'Gender': {'Male': 0, 'Female': 1}}, inplace=True)  # Replace categorical values
# Out:
# <ipython-input-67-14dbef926f8f>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Gender': {'Male': 0, 'Female': 1}}, inplace=True)  # Replace categorical values

# %% [markdown]
# # Add derived column

# %%
df['bonus'] = df['Salary'] * 0.1  # Add derived column

# %% [markdown]
#   # Select salary for age > 30

# %%
df.loc[df['Age'] > 30, 'Salary']  # Select salary for age > 30
# Out:
# 0        198266
# 1         96803
# 3         85591
# 5        143252
# 6         92623
#           ...
# 38437     96730
# 38438     65465
# 38441     55301
# 38442    171459
# 38443    189967
# Name: Salary, Length: 27919, dtype: int64

# %% [markdown]
#  # Select a range of columns

# %%
df.iloc[:, 2:5]  # Select a range of columns
# Out:
#        Age  Gender Education Level
# 0       48       0     High School
# 1       44       0        Master's
# 2       21       1        Master's
# 3       33       0             PhD
# 4       28       1             PhD
# ...    ...     ...             ...
# 38439   24       1     High School
# 38440   21       1     High School
# 38441   35       1     High School
# 38442   35       0             PhD
# 38443   37       0        Master's
#
# [38444 rows x 3 columns]

# %% [markdown]
#  # Select first 5 rows

# %%
df.iloc[0:5, :]  # Select first 5 rows
# Out:
#   Field of Study Current Occupation  Age  Gender Education Level  \
# 0       Medicine   Business Analyst   48       0     High School
# 1      Education          Economist   44       0        Master's
# 2      Education          Biologist   21       1        Master's
# 3      Education   Business Analyst   33       0             PhD
# 4           Arts             Doctor   28       1             PhD
#
#   Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0                 High                 7                 10
# 1                  Low                10                  3
# 2                  Low                 8                  3
# 3               Medium                 7                  9
# 4                  Low                 3                  1
#
#    Job Opportunities  Salary  ...  Certifications  Freelancing Experience  \
# 0                 83  198266  ...               0                       0
# ...

# %% [markdown]
#  # Rows with salary above average

# %%
df[df['Salary'] > df['Salary'].mean()]  # Rows with salary above average
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48       0
# 5                    Medicine               Lawyer   56       0
# 8            Computer Science   Software Developer   31       1
# 9                    Business               Doctor   30       1
# 11                       Arts               Artist   54       0
# ...                       ...                  ...  ...     ...
# 38436  Mechanical Engineering            Economist   30       0
# 38439                 Biology     Business Analyst   24       1
# 38440  Mechanical Engineering               Artist   21       1
# 38442                    Arts     Business Analyst   35       0
# 38443                     Law  Mechanical Engineer   37       0
#
#       Education Level Industry Growth Rate  Job Satisfaction  \
# 0         High School                 High                 7
# 5          Bachelor's                  Low                 3
# ...

# %% [markdown]
# # Filter rows by query

# %%
df.query("Age == 51 and Gender == 'Female'")  # Filter rows by query
# Out:
# Empty DataFrame
# Columns: [Field of Study, Current Occupation, Age, Gender, Education Level, Industry Growth Rate, Job Satisfaction, Work-Life Balance, Job Opportunities, Salary, Job Security, Career Change Interest, Skills Gap, Family Influence, Mentorship Available, Certifications, Freelancing Experience, Geographic Mobility, Professional Networks, Career Change Events, Technology Adoption, Likely to Change Occupation, Name_length, is_high_earner, bonus]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
#   # Access specific value

# %%
df.at[10, 'Salary']  # Access specific value
# Out:
# 77254

# %% [markdown]
#  # Access value by position

# %%
df.iat[5, 3]  # Access value by position
# Out:
# 'Male'

# %% [markdown]
# # Access row by index

# %%
df.loc[10, :]  # Access row by index
# Out:
# Field of Study                   Business
# Current Occupation                 Doctor
# Age                                    52
# Gender                             Female
# Years of Experience                    38
# Education Level                Bachelor's
# Industry Growth Rate                 High
# Job Satisfaction                        9
# Work-Life Balance                       9
# Job Opportunities                      50
# Salary                              77254
# Job Security                           10
# Career Change Interest                  0
# Skills Gap                             10
# Family Influence                     High
# Mentorship Available                    0
# Certifications                          0
# Freelancing Experience                  0
# Geographic Mobility                     0
# Professional Networks                   5
# Career Change Events                    0
# Technology Adoption                     7
# ...

# %% [markdown]
#  # Access row by position

# %%
df.iloc[10]  # Access row by position
# Out:
# Field of Study                   Business
# Current Occupation                 Doctor
# Age                                    52
# Gender                             Female
# Years of Experience                    38
# Education Level                Bachelor's
# Industry Growth Rate                 High
# Job Satisfaction                        9
# Work-Life Balance                       9
# Job Opportunities                      50
# Salary                              77254
# Job Security                           10
# Career Change Interest                  0
# Skills Gap                             10
# Family Influence                     High
# Mentorship Available                    0
# Certifications                          0
# Freelancing Experience                  0
# Geographic Mobility                     0
# Professional Networks                   5
# Career Change Events                    0
# Technology Adoption                     7
# ...

# %% [markdown]
#  # Columns with 'salary' in name

# %%
df.filter(regex='Salary')  # Columns with 'salary' in name
# Out:
#        Salary
# 0      198266
# 1       96803
# 2       65920
# 3       85591
# 4       43986
# ...       ...
# 38439  117728
# 38440  132500
# 38441   55301
# 38442  171459
# 38443  189967
#
# [38444 rows x 1 columns]

# %% [markdown]
#  # Columns containing 'age'

# %%
df.loc[:, df.columns.str.contains('Age')]  # Columns containing 'age'
# Out:
#        Age
# 0       48
# 1       44
# 2       21
# 3       33
# 4       28
# ...    ...
# 38439   24
# 38440   21
# 38441   35
# 38442   35
# 38443   37
#
# [38444 rows x 1 columns]

# %% [markdown]
#  # 10% random sample of rows

# %%
df.sample(frac=0.1)  # 10% random sample of rows
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 18219                Business     Business Analyst   22  Female
# 16315                Medicine              Teacher   27  Female
# 23791                 Biology  Mechanical Engineer   24    Male
# 5003                      Law              Teacher   34    Male
# 27164  Mechanical Engineering   Software Developer   53    Male
# ...                       ...                  ...  ...     ...
# 22782               Education               Lawyer   44    Male
# 5448                Economics            Economist   42    Male
# 27546                Medicine               Doctor   47    Male
# 2551                 Business   Software Developer   24    Male
# 19135        Computer Science               Lawyer   25  Female
#
#        Years of Experience Education Level Industry Growth Rate  \
# 18219                   37             PhD                  Low
# 16315                   11     High School                 High
# ...

# %% [markdown]
#  # Reverse rows

# %%
df.iloc[::-1]  # Reverse rows
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 38443                     Law  Mechanical Engineer   37    Male
# 38442                    Arts     Business Analyst   35    Male
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38439                 Biology     Business Analyst   24  Female
# ...                       ...                  ...  ...     ...
# 4                        Arts               Doctor   28  Female
# 3                   Education     Business Analyst   33    Male
# 2                   Education            Biologist   21  Female
# 1                   Education            Economist   44    Male
# 0                    Medicine     Business Analyst   48    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 38443                   23        Master's               Medium
# 38442                   11             PhD               Medium
# ...

# %% [markdown]
#  # Sort columns alphabetically

# %%
df.sort_index(axis=1)  # Sort columns alphabetically
# Out:
#        Age  Career Change Events  Career Change Interest  Certifications  \
# 0       48                     0                       0               0
# 1       44                     1                       0               0
# 2       21                     1                       0               0
# 3       33                     0                       0               0
# 4       28                     0                       0               0
# ...    ...                   ...                     ...             ...
# 38439   24                     1                       1               0
# 38440   21                     0                       1               0
# 38441   35                     1                       0               1
# 38442   35                     2                       0               0
# 38443   37                     2                       0               0
#
#         Current Occupation Education Level Family Influence  \
# ...

# %% [markdown]
#  # Rows with salary in range

# %%
df[df['Salary'].between(50000, 100000)]  # Rows with salary in range
# Out:
#          Field of Study   Current Occupation  Age  Gender  \
# 1             Education            Economist   44    Male
# 2             Education            Biologist   21  Female
# 3             Education     Business Analyst   33    Male
# 6              Medicine   Software Developer   51  Female
# 7              Medicine               Artist   58  Female
# ...                 ...                  ...  ...     ...
# 38423        Psychology              Teacher   26  Female
# 38427          Medicine  Mechanical Engineer   46  Female
# 38437           Biology            Biologist   44  Female
# 38438           Biology     Business Analyst   55    Male
# 38441  Computer Science  Mechanical Engineer   35  Female
#
#        Years of Experience Education Level Industry Growth Rate  \
# 1                       26        Master's                  Low
# 2                       27        Master's                  Low
# 3                       14             PhD               Medium
# ...

# %% [markdown]
#   # Mean salary by Current Occupation

# %%
df.groupby('Current Occupation')['Salary'].mean()  # Mean salary by Current Occupation
# Out:
# Current Occupation
# Artist                 115190.512239
# Biologist              114119.514308
# Business Analyst       115203.787714
# Doctor                 114396.658693
# Economist              114802.601805
# Lawyer                 115205.081989
# Mechanical Engineer    116177.034230
# Psychologist           114634.587918
# Software Developer     114722.260021
# Teacher                115301.629696
# Name: Salary, dtype: float64

# %% [markdown]
#   # Median age by Current Occupation and gender

# %%
df.groupby(['Current Occupation', 'Gender'])['Age'].median()  # Median age by Current Occupation and gender
# Out:
# Current Occupation   Gender
# Artist               Female    39.0
#                      Male      39.0
# Biologist            Female    39.0
#                      Male      40.0
# Business Analyst     Female    39.0
#                      Male      40.0
# Doctor               Female    40.0
#                      Male      39.0
# Economist            Female    39.0
#                      Male      40.0
# Lawyer               Female    39.0
#                      Male      40.0
# Mechanical Engineer  Female    39.0
#                      Male      39.0
# Psychologist         Female    40.0
#                      Male      39.0
# Software Developer   Female    40.0
#                      Male      40.0
# Teacher              Female    40.0
#                      Male      40.0
# Name: Age, dtype: float64

# %% [markdown]
#   # Count rows by Years of Experience level

# %%
df.groupby('Years of Experience').size()  # Count rows by Years of Experience level
# Out:
# Years of Experience
# 0     959
# 1     982
# 2     955
# 3     962
# 4     980
# 5     917
# 6     942
# 7     958
# 8     966
# 9     935
# 10    986
# 11    981
# 12    955
# 13    919
# 14    923
# 15    958
# 16    972
# 17    935
# 18    948
# 19    956
# 20    969
# 21    969
# 22    987
# 23    988
# 24    988
# 25    956
# 26    947
# 27    921
# 28    977
# 29    963
# 30    999
# 31    981
# 32    956
# 33    966
# 34    958
# 35    967
# 36    982
# 37    943
# 38    942
# 39    996
# dtype: int64

# %% [markdown]
#   # Aggregate stats for salary

# %%
df.groupby('Current Occupation').agg({'Salary': ['mean', 'max', 'min']})  # Aggregate stats for salary
# Out:
#                             Salary
#                               mean     max    min
# Current Occupation
# Artist               115190.512239  199979  30079
# Biologist            114119.514308  199985  30070
# Business Analyst     115203.787714  199992  30005
# Doctor               114396.658693  199955  30010
# Economist            114802.601805  199966  30029
# Lawyer               115205.081989  199921  30016
# Mechanical Engineer  116177.034230  199875  30047
# Psychologist         114634.587918  199991  30008
# Software Developer   114722.260021  199996  30071
# Teacher              115301.629696  199976  30025

# %% [markdown]
#  # Pivot table

# %%
df.pivot_table(values='Salary', index='Current Occupation', columns='Gender', aggfunc='mean')  # Pivot table
# Out:
# Gender                      Female           Male
# Current Occupation
# Artist               114509.379115  115874.106866
# Biologist            113271.420521  114962.231907
# Business Analyst     116353.013306  114024.382878
# Doctor               114328.339886  114464.208696
# Economist            115759.342357  113845.353160
# Lawyer               117059.655971  113329.792021
# Mechanical Engineer  117165.586297  115190.030809
# Psychologist         114154.863544  115123.777259
# Software Developer   114044.624748  115429.790966
# Teacher              115064.174407  115537.866016

# %% [markdown]
#   # Filter groups

# %%
df.groupby('Current Occupation').filter(lambda x: x['Salary'].mean() > 70000)  # Filter groups
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48    Male
# 1                   Education            Economist   44    Male
# 2                   Education            Biologist   21  Female
# 3                   Education     Business Analyst   33    Male
# 4                        Arts               Doctor   28  Female
# ...                       ...                  ...  ...     ...
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %% [markdown]
#  # Cumulative sum within groups

# %%
df.groupby('Current Occupation')['Salary'].cumsum()  # Cumulative sum within groups
# Out:
# 0           198266
# 1            96803
# 2            65920
# 3           283857
# 4            43986
#            ...
# 38439    444284754
# 38440    447054378
# 38441    444419543
# 38442    444456213
# 38443    444609510
# Name: Salary, Length: 38444, dtype: int64

# %% [markdown]
#  # Histogram of salary

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['Salary'].plot(kind='hist')  # Histogram of Salary
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
#   # Boxplot by Current Occupation

# %%
sns.boxplot(x='Current Occupation', y='Salary', data=df)  # Boxplot by Current Occupation
# Out:
# <Axes: xlabel='Current Occupation', ylabel='Salary'>

# %% [markdown]
#   # Correlation heatmap

# %%
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix for numeric columns only
corr_matrix = numeric_df.corr()

# Generate the heatmap using the numeric correlation matrix
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
#  # Line plot for age

# %%
df['Age'].plot(kind='line')  # Line plot for age
# Out:
# <Axes: >

# %% [markdown]
#  # Bar chart for experience

# %%
df['Years of Experience'].value_counts().plot(kind='bar')  # Bar chart for Years of Experience
# Out:
# <Axes: xlabel='Years of Experience'>

# %% [markdown]
#  # Scatterplot

# %%
sns.scatterplot(x='Age', y='Salary', hue='Current Occupation', data=df)  # Scatterplot
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>
